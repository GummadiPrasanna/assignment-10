# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\hp\Documents\prasanna-pandas\assignment-10\friendsnames.xlsx")
df.head()
# Out:
#    S.No friendname      quality
# 0     1   mammatha  responsible
# 1     2    meghana       hepful
# 2     3   siromani   talkactive
# 3     4    bhavani        anger
# 4     5  chandrika         good

# %%
df.tail()
# Out:
#    S.No friendname      quality
# 5     6     pavani        funny
# 6     7    sravani  intelligent
# 7     8    sujatha  hardworking
# 8     9     anusha  intelligent
# 9    10     swathi  hardworking

# %%
#1. Create a friend_names.xls file  (atleast 10 names, columns are FriendName,Quality)
#Q1> create a dataframe which contains only your intelligent friends list.
#Q2> create a dataframe which contains only your funny friends list.

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\hp\Documents\prasanna-pandas\assignment-10\friendsnames.xlsx")
df_f=df[df["quality"]=="intelligent"]
df_f
# Out:
#    S.No friendname      quality
# 6     7    sravani  intelligent
# 8     9     anusha  intelligent

# %%
df_f=df[df["quality"]=="funny"]
df_f
# Out:
#    S.No friendname quality
# 5     6     pavani   funny

# %%
#2. Create a family_members.xls file  (atleast 10 names, columns are FamilyMemberName*Relation)
#Q1> create a dataframe which contains only your brothers and sisters list.
#Q2> create a dataframe which contains only your parents list.
#Q3> create a dataframe which not contains your parents list.
#Q4> create a dataframe which not contains your brothers list.
#Q5> create a dataframe which contains either your brothers list or parents list.

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\hp\Documents\prasanna-pandas\assignment-10\familymembers.xlsx",sheet_name="Sheet2")
df
# Out:
#    S.No familymembername        relation
# 0     1    gopalakrishna         husband
# 1     2       veeraswamy           uncle
# 2     3  venkateswaramma            aunt
# 3     4     srinivasarao          father
# 4     5          sujatha          mother
# 5     6          sravani          sister
# 6     7           chitra          sister
# 7     8            pawan  brother-in-law
# 8     9             teja         brother
# 9    10        narasamma    grand_mother

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\hp\Documents\prasanna-pandas\assignment-10\familymembers.xlsx")
family_and=df[(df["relation"]=="brother")|(df["relation"]=="sister")]
family_and
# Out:
#    S.No familymembername relation
# 5     6          sravani   sister
# 6     7           chitra   sister
# 8     9             teja  brother

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\hp\Documents\prasanna-pandas\assignment-10\familymembers.xlsx",sheet_name="Sheet2")
family_and=df[(df["relation"]=="father")|(df["relation"]=="mother")]
family_and
# Out:
#    S.No familymembername relation
# 3     4     srinivasarao   father
# 4     5          sujatha   mother

# %%
family_and=df[(df["relation"]!="father")&(df["relation"]!="mother")]
family_and
# Out:
#    S.No familymembername        relation
# 0     1    gopalakrishna         husband
# 1     2       veeraswamy           uncle
# 2     3  venkateswaramma            aunt
# 5     6          sravani          sister
# 6     7           chitra          sister
# 7     8            pawan  brother-in-law
# 8     9             teja         brother
# 9    10        narasamma    grand_mother

# %%
family_and=df[df["relation"]!="brother"]
family_and
# Out:
#    S.No familymembername        relation
# 0     1    gopalakrishna         husband
# 1     2       veeraswamy           uncle
# 2     3  venkateswaramma            aunt
# 3     4     srinivasarao          father
# 4     5          sujatha          mother
# 5     6          sravani          sister
# 6     7           chitra          sister
# 7     8            pawan  brother-in-law
# 9    10        narasamma    grand_mother

# %%
family_and=df[(df["relation"]=="brother")|(df["relation"]=="parents")]
family_and
# Out:
#    S.No familymembername relation
# 8     9             teja  brother

# %%
#3. Create a Vegfood_items.xlsx file  (atleast 10 names, columns are VegFoodName*Taste)
#Q1>create a dataframe which are  soups items
#Q2>create a dataframe which are curry items
#Q3>create a dataframe which are fry items
#Q4>create a dataframe which contains soups and fry items
#Q5>create a dataframe which not contains soups and fry items
#Q6>create a dataframe which contains either soup or fry items

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\hp\Documents\prasanna-pandas\assignment-10\vegitems.xlsx")
vegfood=df[df["taste"]=="suop"]
vegfood
# Out:
#    s.no    vegitems taste
# 4     5  tamotosuop  suop

# %%
vegfood=df[df["taste"]=="curry"]
vegfood
# Out:
#    s.no       vegitems  taste
# 0     1   carrot curry  curry
# 6     7  brinjal curry  curry

# %%
vegfood=df[df["taste"]=="fry"]
vegfood
# Out:
#    s.no          vegitems taste
# 5     6        potato fry   fry
# 7     8  ladiesfinger fry   fry

# %%
vegfood=df[(df["taste"]=="suop")^(df["taste"]=="fry")]
vegfood
# Out:
#    s.no          vegitems taste
# 4     5        tamotosuop  suop
# 5     6        potato fry   fry
# 7     8  ladiesfinger fry   fry

# %%
vegfood=df[(df["taste"]!="suop")&(df["taste"]!="fry")]
vegfood
# Out:
#    s.no       vegitems  taste
# 0     1   carrot curry  curry
# 1     2    potatochips    hot
# 2     3    sweetpotato  sweet
# 3     4     vegbriyani  spicy
# 6     7  brinjal curry  curry

# %%
vegfood=df[(df["taste"]=="suop")|(df["taste"]=="fry")]
vegfood
# Out:
#    s.no          vegitems taste
# 4     5        tamotosuop  suop
# 5     6        potato fry   fry
# 7     8  ladiesfinger fry   fry

# %%
#4. Create a NonVegfood_items.xlsx file  (atleast 10 names, columns are NonVegFoodName*Taste)
#Q1>create a dataframe which contains only chicken items
#Q2>create a dataframe which contains only mutton items
#Q3>create a dataframe which contains only Fry items
#Q4>create a dataframe which contains only Fry and chicken items
#Q5>create a dataframe which not contains Fry and chicken items
#Q6>create a dataframe which contains either Fry or mutton items

# %%
import pandas 
import pandas as pd
df=pd.read_excel(r"C:\Users\hp\Documents\prasanna-pandas\assignment-10\nonvegfood.xlsx")
df
# Out:
#    s.no   items     food
# 0     1  chiken    curry
# 1     2  mutton    curry
# 2     3    fish    curry
# 3     4  chiken      fry
# 4     5  mutton      fry
# 5     6    fish      fry
# 6     7  chiken  biryani
# 7     8  mutton  biryani
# 8     9  chiken     soup
# 9    10  mutton    curry

# %%
nonveg=df[df["items"]=="chiken"]
nonveg
# Out:
#    s.no   items     food
# 0     1  chiken    curry
# 3     4  chiken      fry
# 6     7  chiken  biryani
# 8     9  chiken     soup

# %%
nonveg=df[df["food"]=="fry"]
nonveg
# Out:
#    s.no   items food
# 3     4  chiken  fry
# 4     5  mutton  fry
# 5     6    fish  fry

# %%
nonvegfood=df[(df["food"]=="fry")&(df["items"]=="chiken")]
nonvegfood
# Out:
#    s.no   items food
# 3     4  chiken  fry

# %%
nonvegfood=df[(df["food"]!="fry")&(df["items"]!="chiken")]
nonvegfood
# Out:
#    s.no   items     food
# 1     2  mutton    curry
# 2     3    fish    curry
# 7     8  mutton  biryani
# 9    10  mutton    curry

# %%
nonvegfood=df[(df["food"]=="fry")|(df["items"]=="chiken")]
nonvegfood
# Out:
#    s.no   items     food
# 0     1  chiken    curry
# 3     4  chiken      fry
# 4     5  mutton      fry
# 5     6    fish      fry
# 6     7  chiken  biryani
# 8     9  chiken     soup

# %%
#5. Create a month_names.xlsx file (atleast 12 names, columns are MonthName*Season)
#Q1>create a dataframe which contains only winter season months
#Q2>create a dataframe which contains only summer season months
#Q3>create a dataframe which contains only rainy season months
#Q4>create a dataframe which contains only winter and summer season months
#Q5>create a dataframe which not contains summer and rainy season months
#Q6>create a dataframe which contains either winter or rainy items

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\hp\Documents\prasanna-pandas\assignment-10\month_names.xlsx")
df
# Out:
#     s.no     months  season
# 0      1    january  winter
# 1      2   february  winter
# 2      3      march  summer
# 3      4      april  summer
# 4      5        may  summer
# 5      6       june  summer
# 6      7       july   rainy
# 7      8     august   rainy
# 8      9  september   rainy
# 9     10    october   rainy
# 10    11   november  winter
# 11    12   december  winter

# %%
month=df[(df["season"]=="winter")]
month
# Out:
#     s.no    months  season
# 0      1   january  winter
# 1      2  february  winter
# 10    11  november  winter
# 11    12  december  winter

# %%
month=df[(df["season"]=="summer")]
month
# Out:
#    s.no months  season
# 2     3  march  summer
# 3     4  april  summer
# 4     5    may  summer
# 5     6   june  summer

# %%
month=df[(df["season"]=="rainy")]
month
# Out:
#    s.no     months season
# 6     7       july  rainy
# 7     8     august  rainy
# 8     9  september  rainy
# 9    10    october  rainy

# %%
month=df[(df["season"]=="winter")|(df["season"]=="summer")]
month
# Out:
#     s.no    months  season
# 0      1   january  winter
# 1      2  february  winter
# 2      3     march  summer
# 3      4     april  summer
# 4      5       may  summer
# 5      6      june  summer
# 10    11  november  winter
# 11    12  december  winter

# %%
month=df[(df["season"]!="summer")&(df["season"]!="rainy")]
month
# Out:
#     s.no    months  season
# 0      1   january  winter
# 1      2  february  winter
# 10    11  november  winter
# 11    12  december  winter

# %%
month=df[(df["season"]=="winter")|(df["season"]=="rainy")]
month
# Out:
#     s.no     months  season
# 0      1    january  winter
# 1      2   february  winter
# 6      7       july   rainy
# 7      8     august   rainy
# 8      9  september   rainy
# 9     10    october   rainy
# 10    11   november  winter
# 11    12   december  winter

# %%
#6. Create a flower_names.xlsx file  (atleast 12 names, columns are FlowercolourName_in_English^FlowercolourName_in_Hindi^FlowercolourName_in_Telugu)
#Q1>create a dataframe which contains only red colour flower list
#Q2>create a dataframe which contains only white colour flower list
#Q3>create a dataframe which contains only pink colour flower list
#Q4>create a dataframe which contains only red and pink colour list
#Q5>create a dataframe which not contains red and white colour list
#Q6>create a dataframe which contains either red or pink colour list

# %%
import pandas
import pandas as pd
df=pd.read_excel(r"C:\Users\hp\Documents\prasanna-pandas\assignment-10\flowers.xlsx")
df
# Out:
#     s.no colour   english       hindi      telugu
# 0      1    red      rose      gulaab      gulabi
# 1      2    red     tulip     tyoolip      tulips
# 2      3    red  hibiscus  japaapushp   mandharam
# 3      4    red     lilly       lilee       lilly
# 4      5  white      rose      gulaab      gulabi
# 5      6  white     tulip     tyoolip      tulips
# 6      7  white     lilly       lilee       lilly
# 7      8  white   jasmine   chamelee   mallepuvvu
# 8      9   pink      rose      gulaab      gulabi
# 9     10   pink  hibiscus  japaapushp   mandharam
# 10    11   pink     lilly       lilee       lilly
# 11    12   pink     tulip     tyoolip      tulips

# %%
flower=df[(df["colour"]=="red")]
flower
# Out:
#    s.no colour   english       hindi     telugu
# 0     1    red      rose      gulaab     gulabi
# 1     2    red     tulip     tyoolip     tulips
# 2     3    red  hibiscus  japaapushp  mandharam
# 3     4    red     lilly       lilee      lilly

# %%
flower=df[(df["colour"]=="white")]
flower
# Out:
#    s.no colour  english      hindi      telugu
# 4     5  white     rose     gulaab      gulabi
# 5     6  white    tulip    tyoolip      tulips
# 6     7  white    lilly      lilee       lilly
# 7     8  white  jasmine  chamelee   mallepuvvu

# %%
flower=df[(df["colour"]=="pink")]
flower
# Out:
#     s.no colour   english       hindi     telugu
# 8      9   pink      rose      gulaab     gulabi
# 9     10   pink  hibiscus  japaapushp  mandharam
# 10    11   pink     lilly       lilee      lilly
# 11    12   pink     tulip     tyoolip     tulips

# %%
flower=df[(df["colour"]=="red")|(df["colour"]=="pink")]
flower
# Out:
#     s.no colour   english       hindi     telugu
# 0      1    red      rose      gulaab     gulabi
# 1      2    red     tulip     tyoolip     tulips
# 2      3    red  hibiscus  japaapushp  mandharam
# 3      4    red     lilly       lilee      lilly
# 8      9   pink      rose      gulaab     gulabi
# 9     10   pink  hibiscus  japaapushp  mandharam
# 10    11   pink     lilly       lilee      lilly
# 11    12   pink     tulip     tyoolip     tulips

# %%
flower=df[(df["colour"]!="red")&(df["colour"]!="white")]
flower
# Out:
#     s.no colour   english       hindi     telugu
# 8      9   pink      rose      gulaab     gulabi
# 9     10   pink  hibiscus  japaapushp  mandharam
# 10    11   pink     lilly       lilee      lilly
# 11    12   pink     tulip     tyoolip     tulips

# %%
flower=df[(df["colour"]=="red")|(df["colour"]=="pink")]
flower
# Out:
#     s.no colour   english       hindi     telugu
# 0      1    red      rose      gulaab     gulabi
# 1      2    red     tulip     tyoolip     tulips
# 2      3    red  hibiscus  japaapushp  mandharam
# 3      4    red     lilly       lilee      lilly
# 8      9   pink      rose      gulaab     gulabi
# 9     10   pink  hibiscus  japaapushp  mandharam
# 10    11   pink     lilly       lilee      lilly
# 11    12   pink     tulip     tyoolip     tulips
